# %% [markdown]
# # Notes
#
# ## Bots on Polymarket
#
# I've found a [market that was resolved almost 2 years ago](https://polymarket.com/event/will-btc-reach-30000-by-april-7) and has a small volume of just 1000 USD. It has comments that were made just 17 hours ago. There is no way a real person would make comments on such markets. It seems to me that they are all bots. Also, some of the comments are political. This makes me consider that this is part of a campaign to bloat polymarket activity stats, or something else.
#
# ![21_old_market.png](attachment:21_old_market.png)
#
# ![22_weird_comments.png](attachment:22_weird_comments.png)
